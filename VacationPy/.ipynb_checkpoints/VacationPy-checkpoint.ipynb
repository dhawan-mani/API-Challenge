# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager
# Out:
# Building jupyterlab assets (build:prod:minimize)

# %%
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in c:\users\sunandan\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\sunandan\anaconda3\lib\site-packages (from gmaps) (7.12.0)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\sunandan\anaconda3\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\sunandan\anaconda3\lib\site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: six in c:\users\sunandan\anaconda3\lib\site-packages (from gmaps) (1.14.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\sunandan\anaconda3\lib\site-packages (from gmaps) (4.3.3)
# Requirement already satisfied: decorator in c:\users\sunandan\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.1)
# Requirement already satisfied: jedi>=0.10 in c:\users\sunandan\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.14.1)
# Requirement already satisfied: pygments in c:\users\sunandan\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.5.2)
# Requirement already satisfied: backcall in c:\users\sunandan\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: pickleshare in c:\users\sunandan\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\sunandan\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\sunandan\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.3)
# Requirement already satisfied: setuptools>=18.5 in c:\users\sunandan\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (45.2.0.post20200210)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\sunandan\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\sunandan\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\sunandan\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.4)
# Requirement already satisfied: ipython-genutils in c:\users\sunandan\anaconda3\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: parso>=0.5.0 in c:\users\sunandan\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.5.2)
# Requirement already satisfied: wcwidth in c:\users\sunandan\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.1.8)
# Requirement already satisfied: jupyter-client in c:\users\sunandan\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: tornado>=4.2 in c:\users\sunandan\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\sunandan\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: jupyter-core in c:\users\sunandan\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\sunandan\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\sunandan\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (227)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\sunandan\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\sunandan\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (18.1.1)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\sunandan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.3)
# Requirement already satisfied: prometheus-client in c:\users\sunandan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: jinja2 in c:\users\sunandan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.1)
# Requirement already satisfied: nbconvert in c:\users\sunandan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.6.1)
# Requirement already satisfied: Send2Trash in c:\users\sunandan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\sunandan\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.15.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\sunandan\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\sunandan\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.3.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sunandan\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\sunandan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sunandan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: testpath in c:\users\sunandan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\sunandan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: bleach in c:\users\sunandan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.0)
# Requirement already satisfied: defusedxml in c:\users\sunandan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\sunandan\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.2.0)
# Requirement already satisfied: webencodings in c:\users\sunandan\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)

# %%
! jupyter lab build
# Out:
# [LabBuildApp] JupyterLab 2.1.5
# [LabBuildApp] Building in c:\users\sunandan\anaconda3\share\jupyter\lab
# [LabBuildApp] Building jupyterlab assets (build:prod:minimize)

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
import ipywidgets as widgets
widgets.IntSlider()
# Import API key
from api_keys import g_key
gmaps.configure(api_key=g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
Df = pd.read_csv("../WeatherPy/Output.csv")

# %%
Weather_Data = Df.iloc[:,1:10]
Weather_Data.info()

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
locations = Weather_Data[["Lat","Lng"]]
Weights = Weather_Data["Humidity"].astype(float)

# %%
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=Weights, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)
fig.add_layer(heat_layer)
fig = gmaps.figure()
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
Hotel_df = Weather_Data.loc[(Weather_Data["MaxTemp"] >70) & (Weather_Data["MaxTemp"]<80) & (Weather_Data["Wind Speed"]<10) & (Weather_Data["Cloudiness"]==0)]

# %%
Hotel_df.reset_index(inplace=True)

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = Hotel_df.iloc[:,1:10]

# %%
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#           City    Lat    Lng  MaxTemp  Humidity  Cloudiness  Wind Speed  \
# 0        yalta  44.50  34.17    75.63      52.0         0.0        5.61
# 1       tukrah  32.53  20.58    76.95      76.0         0.0        9.24
# 2        volax  41.32  24.00    79.00      64.0         0.0        2.24
# 3          gat  31.61  34.76    77.00      62.0         0.0        3.78
# 4         jawa  31.85  35.94    78.80      39.0         0.0        5.59
# 5   troitskoye  52.98  84.68    70.99      50.0         0.0        4.85
# 6         faya  18.39  42.45    73.40      49.0         0.0        5.93
# 7       kerman  30.28  57.08    77.00      13.0         0.0        4.70
# 8       usinsk  65.99  57.53    75.88      48.0         0.0        8.41
# 9       tiznit  29.58  -9.50    76.87      37.0         0.0        1.03
# 10   fiumicino  41.77  12.23    75.00      72.0         0.0        2.24
# 11     klyuchi  52.27  79.17    74.86      44.0         0.0        4.38
# 12    timizart  36.80   4.27    73.08      65.0         0.0        6.51
#
#    Country          Date Hotel Name
# 0       UA  1.595481e+09
# 1       LY  1.595481e+09
# 2       GR  1.595481e+09
# 3       IL  1.595481e+09
# 4       JO  1.595481e+09
# 5       RU  1.595481e+09
# 6       SA  1.595481e+09
# 7       IR  1.595481e+09
# 8       RU  1.595481e+09
# 9       MA  1.595481e+09
# 10      IT  1.595481e+09
# 11      RU  1.595481e+09
# 12      DZ  1.595481e+09

# %%
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "key" : g_key,
    "radius": 5000,
    "types":"hotel" ,
    "keyword" :"Nearby Hotel"}
for index,row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    response = requests.get(url,params=params).json()
    if (len(response["results"]) > 0):
        hotel_df.loc[index,"Hotel Name"] = response["results"][0]["name"]
print("DONE")
hotel_df
# Out:
# DONE
#           City    Lat    Lng  MaxTemp  Humidity  Cloudiness  Wind Speed  \
# 0        yalta  44.50  34.17    75.63      52.0         0.0        5.61
# 1       tukrah  32.53  20.58    76.95      76.0         0.0        9.24
# 2        volax  41.32  24.00    79.00      64.0         0.0        2.24
# 3          gat  31.61  34.76    77.00      62.0         0.0        3.78
# 4         jawa  31.85  35.94    78.80      39.0         0.0        5.59
# 5   troitskoye  52.98  84.68    70.99      50.0         0.0        4.85
# 6         faya  18.39  42.45    73.40      49.0         0.0        5.93
# 7       kerman  30.28  57.08    77.00      13.0         0.0        4.70
# 8       usinsk  65.99  57.53    75.88      48.0         0.0        8.41
# 9       tiznit  29.58  -9.50    76.87      37.0         0.0        1.03
# 10   fiumicino  41.77  12.23    75.00      72.0         0.0        2.24
# 11     klyuchi  52.27  79.17    74.86      44.0         0.0        4.38
# 12    timizart  36.80   4.27    73.08      65.0         0.0        6.51
#
#    Country          Date                Hotel Name
# 0       UA  1.595481e+09                 Massandra
# 1       LY  1.595481e+09
# 2       GR  1.595481e+09           ALONI HOTEL&SPA
# 3       IL  1.595481e+09                Desert Gat
# 4       JO  1.595481e+09                Opal Hotel
# 5       RU  1.595481e+09
# 6       SA  1.595481e+09
# 7       IR  1.595481e+09
# 8       RU  1.595481e+09  Gostinitsa "Uyutnyy Dom"
# 9       MA  1.595481e+09
# 10      IT  1.595481e+09       Guest House La Lira
# 11      RU  1.595481e+09
# 12      DZ  1.595481e+09

# %%
hotel_df = hotel_df.loc[(hotel_df["Hotel Name"]!="")]

# %%
hotel_df
# Out:
#          City    Lat    Lng  MaxTemp  Humidity  Cloudiness  Wind Speed  \
# 0       yalta  44.50  34.17    75.63      52.0         0.0        5.61
# 2       volax  41.32  24.00    79.00      64.0         0.0        2.24
# 3         gat  31.61  34.76    77.00      62.0         0.0        3.78
# 4        jawa  31.85  35.94    78.80      39.0         0.0        5.59
# 8      usinsk  65.99  57.53    75.88      48.0         0.0        8.41
# 10  fiumicino  41.77  12.23    75.00      72.0         0.0        2.24
#
#    Country          Date                Hotel Name
# 0       UA  1.595481e+09                 Massandra
# 2       GR  1.595481e+09           ALONI HOTEL&SPA
# 3       IL  1.595481e+09                Desert Gat
# 4       JO  1.595481e+09                Opal Hotel
# 8       RU  1.595481e+09  Gostinitsa "Uyutnyy Dom"
# 10      IT  1.595481e+09       Guest House La Lira

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

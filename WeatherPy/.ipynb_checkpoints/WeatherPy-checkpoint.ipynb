# %% [markdown]
# #WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import time
import json
from scipy.stats import linregress
import scipy.stats as st
from api_keys import weather_api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#List for holding lat_lngs and cities
Lat_lng = []
cities = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
len(cities)
cities[0]
# Out:
# 'margate'

# %%
Cities_Dict = {"City":cities,"Lat":"","Lng":"","MaxTemp":"","Humidity":"","Cloudiness":"","Wind Speed":"","Country":"","Date":""}
Cities_df = pd.DataFrame(Cities_Dict)
Cities_df
# Out:
#                 City Lat Lng MaxTemp Humidity Cloudiness Wind Speed Country  \
# 0            margate
# 1       puerto ayora
# 2       beringovskiy
# 3    arraial do cabo
# 4              yalta
# ..               ...  ..  ..     ...      ...        ...        ...     ...
# 619         manakara
# 620          ngukurr
# 621          kharian
# 622            ngong
# 623    cockburn town
#
#     Date
# 0
# 1
# 2
# 3
# 4
# ..   ...
# 619
# 620
# 621
# 622
# 623
#
# [624 rows x 9 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
record_number = 1
set_number = 1
print("Beginning data retrieval")
print("---------------------------------")
for index,row in Cities_df.iterrows():
    city = row['City']
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=Imperial"
    response = requests.get(url).json()
    try:
        print(f"Processing Record {record_number} of Set {set_number} | {city}")
        Cities_df.loc[index,"Lat"] = response["coord"]["lat"]
        Cities_df.loc[index,"Lng"] = response["coord"]["lon"]
        Cities_df.loc[index,"MaxTemp"] = response["main"]["temp_max"]
        Cities_df.loc[index,"Humidity"] = response["main"]["humidity"]
        Cities_df.loc[index,"Cloudiness"] = response["clouds"]["all"]
        Cities_df.loc[index,"Wind Speed"] = response["wind"]["speed"]
        Cities_df.loc[index,"Country"] = response["sys"]["country"]
        Cities_df.loc[index,"Date"] = response["dt"]
    except (KeyError,IndexError):
        print("City not found.Skipping......")
    record_number = record_number+1
    if record_number==51:
        set_number = set_number + 1
        record_number = 1
print("-------------------------")   
print("Data Retrieval Complete")
print("-------------------------")
#print(json.dumps(response,indent = 4,sort_keys=True))
# counter = 0
# set = 1
# for index,row in Cities_df.iterrows():
#     url = "api.openweathermap.org/data/2.5/weather?q={row['city']}&appid={weather_api_key}"
#     response = requests.get(url).json()

#     try:
#          print(f"Processing Record {counter} of Set {set}|{row["City"]}")
#     except (KeyError,IndexError):
#         print("city not found")
# counter = counter + 1
# if counter == 50:
#     set = set + 1
# Out:
# Beginning data retrieval
# ---------------------------------
# Processing Record 1 of Set 1 | margate
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | beringovskiy
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | yalta
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | sidi qasim
# City not found.Skipping......
# Processing Record 8 of Set 1 | orange
# Processing Record 9 of Set 1 | walvis bay
# Processing Record 10 of Set 1 | ano mera
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | coquimbo
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | san cristobal
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | la ronge
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | tommot
# Processing Record 21 of Set 1 | taolanaro
# City not found.Skipping......
# Processing Record 22 of Set 1 | otjiwarongo
# Processing Record 23 of Set 1 | hambantota
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | tura
# Processing Record 28 of Set 1 | balclutha
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | santiago del estero
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | riyadh
# Processing Record 33 of Set 1 | champerico
# Processing Record 34 of Set 1 | umzimvubu
# City not found.Skipping......
# Processing Record 35 of Set 1 | khatanga
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | betare oya
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 
# Processing Record 10 of Set 5 | glace bay
# Processing Record 11 of Set 5 | arlit
# Processing Record 12 of Set 5 | kavaratti
# Processing Record 13 of Set 5 | ziro
# Processing Record 14 of Set 5 | palmer
# Processing Record 15 of Set 5 | mayya
# Processing Record 16 of Set 5 | chokurdakh
# Processing Record 17 of Set 5 | sentyabrskiy
# City not found.Skipping......
# Processing Record 18 of Set 5 | kavieng
# Processing Record 19 of Set 5 | morondava
# Processing Record 20 of Set 5 | shitanjing
# Processing Record 21 of Set 5 | kaitangata
# Processing Record 22 of Set 5 | tezu
# Processing Record 23 of Set 5 | ayna
# Processing Record 24 of Set 5 | kenora
# Processing Record 25 of Set 5 | camargo
# Processing Record 26 of Set 5 | hue
# Processing Record 27 of Set 5 | belushya guba
# City not found.Skipping......
# Processing Record 28 of Set 5 | dekar
# Processing Record 29 of Set 5 | ghorawal
# Processing Record 30 of Set 5 | beyneu
# Processing Record 31 of Set 5 | tahe
# Processing Record 32 of Set 5 | erenhot
# Processing Record 33 of Set 5 | lavrentiya
# Processing Record 34 of Set 5 | kamenka
# Processing Record 35 of Set 5 | antalaha
# Processing Record 36 of Set 5 | jagatsinghapur
# Processing Record 37 of Set 5 | pavino
# Processing Record 38 of Set 5 | ullapool
# Processing Record 39 of Set 5 | nyurba
# Processing Record 40 of Set 5 | deputatskiy
# Processing Record 41 of Set 5 | lompoc
# Processing Record 42 of Set 5 | fort nelson
# Processing Record 43 of Set 5 | huilong
# Processing Record 44 of Set 5 | novouzensk
# Processing Record 45 of Set 5 | hualmay
# Processing Record 46 of Set 5 | valparaiso
# Processing Record 47 of Set 5 | deggendorf
# Processing Record 48 of Set 5 | hamilton
# Processing Record 49 of Set 5 | wageningen
# Processing Record 50 of Set 5 | aklavik
# Processing Record 1 of Set 6 | baykit
# Processing Record 2 of Set 6 | aksarka
# Processing Record 3 of Set 6 | rock springs
# Processing Record 4 of Set 6 | rawson
# Processing Record 5 of Set 6 | richards bay
# Processing Record 6 of Set 6 | hobyo
# Processing Record 7 of Set 6 | montepuez
# Processing Record 8 of Set 6 | les cayes
# Processing Record 9 of Set 6 | zaysan
# Processing Record 10 of Set 6 | hasaki
# Processing Record 11 of Set 6 | moose factory
# Processing Record 12 of Set 6 | esil
# Processing Record 13 of Set 6 | baoqing
# Processing Record 14 of Set 6 | faanui
# Processing Record 15 of Set 6 | nome
# Processing Record 16 of Set 6 | wajima
# Processing Record 17 of Set 6 | aykhal
# Processing Record 18 of Set 6 | saint-augustin
# Processing Record 19 of Set 6 | alice springs
# Processing Record 20 of Set 6 | yellowknife
# Processing Record 21 of Set 6 | nizhniy baskunchak
# Processing Record 22 of Set 6 | taburao
# City not found.Skipping......
# Processing Record 23 of Set 6 | northam
# Processing Record 24 of Set 6 | hofn
# Processing Record 25 of Set 6 | smolensk
# Processing Record 26 of Set 6 | lorengau
# Processing Record 27 of Set 6 | grand gaube
# Processing Record 28 of Set 6 | codrington
# Processing Record 29 of Set 6 | victor harbor
# Processing Record 30 of Set 6 | aksu
# Processing Record 31 of Set 6 | tabuk
# Processing Record 32 of Set 6 | acajutla
# Processing Record 33 of Set 6 | tazovskiy
# Processing Record 34 of Set 6 | dunedin
# Processing Record 35 of Set 6 | sataua
# City not found.Skipping......
# Processing Record 36 of Set 6 | urusha
# Processing Record 37 of Set 6 | te anau
# Processing Record 38 of Set 6 | yulara
# Processing Record 39 of Set 6 | constitucion
# Processing Record 40 of Set 6 | manzhouli
# Processing Record 41 of Set 6 | blagoyevo
# Processing Record 42 of Set 6 | upernavik
# Processing Record 43 of Set 6 | alta floresta
# Processing Record 44 of Set 6 | ilulissat
# Processing Record 45 of Set 6 | mandalgovi
# Processing Record 46 of Set 6 | ca mau
# Processing Record 47 of Set 6 | comodoro rivadavia
# Processing Record 48 of Set 6 | gualaquiza
# Processing Record 49 of Set 6 | kapit
# Processing Record 50 of Set 6 | san patricio
# Processing Record 1 of Set 7 | nakamura
# Processing Record 2 of Set 7 | saint-georges
# Processing Record 3 of Set 7 | ohangaron
# Processing Record 4 of Set 7 | kristianstad
# Processing Record 5 of Set 7 | la cruz
# Processing Record 6 of Set 7 | tasiilaq
# Processing Record 7 of Set 7 | lakatoro
# Processing Record 8 of Set 7 | port lincoln
# Processing Record 9 of Set 7 | muyinga
# Processing Record 10 of Set 7 | nizhneyansk
# City not found.Skipping......
# Processing Record 11 of Set 7 | nouakchott
# Processing Record 12 of Set 7 | samusu
# City not found.Skipping......
# Processing Record 13 of Set 7 | anadyr
# Processing Record 14 of Set 7 | luau
# Processing Record 15 of Set 7 | norman wells
# Processing Record 16 of Set 7 | seoul
# Processing Record 17 of Set 7 | port macquarie
# Processing Record 18 of Set 7 | ponta do sol
# Processing Record 19 of Set 7 | maldonado
# Processing Record 20 of Set 7 | kenai
# Processing Record 21 of Set 7 | bakchar
# Processing Record 22 of Set 7 | longyearbyen
# Processing Record 23 of Set 7 | saleaula
# City not found.Skipping......
# Processing Record 24 of Set 7 | cabedelo
# Processing Record 25 of Set 7 | chistogorskiy
# Processing Record 26 of Set 7 | troitskoye
# Processing Record 27 of Set 7 | puerto narino
# Processing Record 28 of Set 7 | half moon bay
# Processing Record 29 of Set 7 | marsa matruh
# Processing Record 30 of Set 7 | lolua
# City not found.Skipping......
# Processing Record 31 of Set 7 | dovolnoye
# Processing Record 32 of Set 7 | griffin
# Processing Record 33 of Set 7 | negrasi
# Processing Record 34 of Set 7 | gorno-chuyskiy
# City not found.Skipping......
# Processing Record 35 of Set 7 | saskylakh
# Processing Record 36 of Set 7 | turukhansk
# Processing Record 37 of Set 7 | komsomolskiy
# Processing Record 38 of Set 7 | noumea
# Processing Record 39 of Set 7 | tsihombe
# City not found.Skipping......
# Processing Record 40 of Set 7 | bohicon
# Processing Record 41 of Set 7 | geresk
# City not found.Skipping......
# Processing Record 42 of Set 7 | south lake tahoe
# Processing Record 43 of Set 7 | znamenskoye
# Processing Record 44 of Set 7 | kruisfontein
# Processing Record 45 of Set 7 | westport
# Processing Record 46 of Set 7 | abha
# Processing Record 47 of Set 7 | kununurra
# Processing Record 17 of Set 9 | plattsburgh
# Processing Record 18 of Set 9 | kemlya
# Processing Record 19 of Set 9 | iqaluit
# Processing Record 20 of Set 9 | samarai
# Processing Record 21 of Set 9 | meulaboh
# Processing Record 22 of Set 9 | hurricane
# Processing Record 23 of Set 9 | totolapan
# Processing Record 24 of Set 9 | alvorada
# Processing Record 25 of Set 9 | severo-kurilsk
# Processing Record 26 of Set 9 | port blair
# Processing Record 27 of Set 9 | tiznit
# Processing Record 28 of Set 9 | rawannawi
# City not found.Skipping......
# Processing Record 29 of Set 9 | ustka
# Processing Record 30 of Set 9 | centralia
# Processing Record 31 of Set 9 | baryatino
# Processing Record 32 of Set 9 | port hardy
# Processing Record 33 of Set 9 | cockburn harbour
# City not found.Skipping......
# Processing Record 34 of Set 9 | mlonggo
# Processing Record 35 of Set 9 | requena
# Processing Record 36 of Set 9 | dori
# Processing Record 37 of Set 9 | chemodanovka
# Processing Record 38 of Set 9 | enshi
# Processing Record 39 of Set 9 | cabo san lucas
# Processing Record 40 of Set 9 | srednekolymsk
# Processing Record 41 of Set 9 | porto velho
# Processing Record 42 of Set 9 | bolungarvik
# City not found.Skipping......
# Processing Record 43 of Set 9 | barquisimeto
# Processing Record 44 of Set 9 | poum
# Processing Record 45 of Set 9 | mazurivka
# Processing Record 46 of Set 9 | byron bay
# Processing Record 47 of Set 9 | sept-iles
# Processing Record 48 of Set 9 | aqtobe
# Processing Record 49 of Set 9 | pyay
# Processing Record 50 of Set 9 | saldanha
# Processing Record 1 of Set 10 | bartica
# Processing Record 2 of Set 10 | saurimo
# Processing Record 3 of Set 10 | bacong
# Processing Record 4 of Set 10 | bardiyah
# Processing Record 5 of Set 10 | maryville
# Processing Record 6 of Set 10 | saint-pierre
# Processing Record 7 of Set 10 | cidreira
# Processing Record 8 of Set 10 | la rochelle
# Processing Record 9 of Set 10 | bolekhiv
# Processing Record 10 of Set 10 | urmary
# Processing Record 11 of Set 10 | itarema
# Processing Record 12 of Set 10 | huanren
# Processing Record 13 of Set 10 | north salt lake
# Processing Record 14 of Set 10 | joao camara
# Processing Record 15 of Set 10 | fairbanks
# Processing Record 16 of Set 10 | vila franca do campo
# Processing Record 17 of Set 10 | andevoranto
# City not found.Skipping......
# Processing Record 18 of Set 10 | mungeli
# Processing Record 19 of Set 10 | san lorenzo
# Processing Record 20 of Set 10 | bahile
# Processing Record 21 of Set 10 | chara
# Processing Record 22 of Set 10 | eyl
# Processing Record 23 of Set 10 | marfino
# Processing Record 24 of Set 10 | turtkul
# City not found.Skipping......
# Processing Record 25 of Set 10 | narsaq
# Processing Record 26 of Set 10 | oum hadjer
# Processing Record 27 of Set 10 | nicoya
# Processing Record 28 of Set 10 | buraydah
# Processing Record 29 of Set 10 | techiman
# Processing Record 30 of Set 10 | alexandria
# Processing Record 31 of Set 10 | yizheng
# Processing Record 32 of Set 10 | bishop auckland
# Processing Record 33 of Set 10 | broken hill
# Processing Record 34 of Set 10 | kushiro
# Processing Record 35 of Set 10 | murwara
# Processing Record 36 of Set 10 | jibuti
# Processing Record 6 of Set 12 | bilibino
# Processing Record 7 of Set 12 | namibe
# Processing Record 8 of Set 12 | derzhavinsk
# Processing Record 9 of Set 12 | chernyshevskiy
# Processing Record 10 of Set 12 | collie
# Processing Record 11 of Set 12 | uray
# Processing Record 12 of Set 12 | netanya
# Processing Record 13 of Set 12 | gloversville
# Processing Record 14 of Set 12 | sinnamary
# Processing Record 15 of Set 12 | urdzhar
# City not found.Skipping......
# Processing Record 16 of Set 12 | masuguru
# Processing Record 17 of Set 12 | jalingo
# Processing Record 18 of Set 12 | andenes
# Processing Record 19 of Set 12 | tabiauea
# City not found.Skipping......
# Processing Record 20 of Set 12 | camacha
# Processing Record 21 of Set 12 | batticaloa
# Processing Record 22 of Set 12 | miquelon
# Processing Record 23 of Set 12 | sakaiminato
# Processing Record 24 of Set 12 | san antonio
# Processing Record 25 of Set 12 | san luis de palenque
# Processing Record 26 of Set 12 | haibowan
# City not found.Skipping......
# Processing Record 27 of Set 12 | shipitsyno
# Processing Record 28 of Set 12 | grindavik
# Processing Record 29 of Set 12 | jutai
# Processing Record 30 of Set 12 | jalu
# Processing Record 31 of Set 12 | eureka
# Processing Record 32 of Set 12 | rongcheng
# Processing Record 33 of Set 12 | pinawa
# Processing Record 34 of Set 12 | dunbar
# Processing Record 35 of Set 12 | gojo
# Processing Record 36 of Set 12 | malakal
# Processing Record 37 of Set 12 | corum
# Processing Record 38 of Set 12 | barmer
# Processing Record 39 of Set 12 | solnechnyy
# Processing Record 40 of Set 12 | columbus
# Processing Record 41 of Set 12 | sahrak
# City not found.Skipping......
# Processing Record 42 of Set 12 | santa barbara
# Processing Record 43 of Set 12 | verkhnyaya toyma
# Processing Record 44 of Set 12 | russell
# Processing Record 45 of Set 12 | bathsheba
# Processing Record 46 of Set 12 | waynesboro
# Processing Record 47 of Set 12 | farafangana
# Processing Record 48 of Set 12 | camopi
# Processing Record 49 of Set 12 | balkanabat
# Processing Record 50 of Set 12 | naryan-mar
# Processing Record 1 of Set 13 | severo-yeniseyskiy
# Processing Record 2 of Set 13 | kamenskoye
# City not found.Skipping......
# Processing Record 3 of Set 13 | gazni
# City not found.Skipping......
# Processing Record 4 of Set 13 | vanimo
# Processing Record 5 of Set 13 | mitu
# Processing Record 6 of Set 13 | joshimath
# Processing Record 7 of Set 13 | banda aceh
# Processing Record 8 of Set 13 | podgornoye
# Processing Record 9 of Set 13 | sri aman
# Processing Record 10 of Set 13 | pokhara
# Processing Record 11 of Set 13 | sambava
# Processing Record 12 of Set 13 | nazca
# Processing Record 13 of Set 13 | tobermory
# Processing Record 14 of Set 13 | lethem
# Processing Record 15 of Set 13 | ugoofaaru
# Processing Record 16 of Set 13 | honiara
# Processing Record 17 of Set 13 | sampit
# Processing Record 18 of Set 13 | beloha
# Processing Record 19 of Set 13 | manavalakurichi
# Processing Record 20 of Set 13 | manakara
# Processing Record 21 of Set 13 | ngukurr
# City not found.Skipping......
# Processing Record 22 of Set 13 | kharian
# Processing Record 23 of Set 13 | ngong
# Processing Record 24 of Set 13 | cockburn town
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
Cities_df
# Out:
#                 City    Lat     Lng MaxTemp Humidity Cloudiness Wind Speed  \
# 0            margate  51.38    1.39      61       70         15       1.99
# 1       puerto ayora  -0.74  -90.35   69.01       93         98          4
# 2       beringovskiy  63.05  179.32   52.52       73          0         14
# 3    arraial do cabo -22.97  -42.03   70.43       87          0      10.51
# 4              yalta   44.5   34.17   75.63       52          0       5.61
# ..               ...    ...     ...     ...      ...        ...        ...
# 619         manakara -22.13   48.02   61.47       82         30       7.85
# 620          ngukurr
# 621          kharian  32.81   73.86    87.8       55          0        4.7
# 622            ngong  -1.36   36.66    57.2       87         75       1.34
# 623    cockburn town  21.46  -71.14   82.81       79         17      20.62
#
#     Country        Date
# 0        GB  1595480845
# 1        EC  1595480845
# 2        RU  1595480845
# 3        BR  1595480570
# 4        UA  1595480846
# ..      ...         ...
# 619      MG  1595480826
# 620
# 621      PK  1595481029
# 622      KE  1595481030
# 623      TC  1595481030
#
# [624 rows x 9 columns]

# %%
Cities_Weather = Cities_df.replace('', np.nan)

# %%
Cities_Weather.dropna(inplace=True)

# %%
New = Cities_Weather.isnull()

# %%
New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 573 entries, 0 to 623
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        573 non-null    bool
#  1   Lat         573 non-null    bool
#  2   Lng         573 non-null    bool
#  3   MaxTemp     573 non-null    bool
#  4   Humidity    573 non-null    bool
#  5   Cloudiness  573 non-null    bool
#  6   Wind Speed  573 non-null    bool
#  7   Country     573 non-null    bool
#  8   Date        573 non-null    bool
# dtypes: bool(9)
# memory usage: 9.5 KB

# %%
Cities_Weather
# Out:
#                 City    Lat     Lng  MaxTemp  Humidity  Cloudiness  \
# 0            margate  51.38    1.39    61.00      70.0        15.0
# 1       puerto ayora  -0.74  -90.35    69.01      93.0        98.0
# 2       beringovskiy  63.05  179.32    52.52      73.0         0.0
# 3    arraial do cabo -22.97  -42.03    70.43      87.0         0.0
# 4              yalta  44.50   34.17    75.63      52.0         0.0
# ..               ...    ...     ...      ...       ...         ...
# 618  manavalakurichi   8.13   77.30    87.80      66.0        40.0
# 619         manakara -22.13   48.02    61.47      82.0        30.0
# 621          kharian  32.81   73.86    87.80      55.0         0.0
# 622            ngong  -1.36   36.66    57.20      87.0        75.0
# 623    cockburn town  21.46  -71.14    82.81      79.0        17.0
#
#      Wind Speed Country          Date
# 0          1.99      GB  1.595481e+09
# 1          4.00      EC  1.595481e+09
# 2         14.00      RU  1.595481e+09
# 3         10.51      BR  1.595481e+09
# 4          5.61      UA  1.595481e+09
# ..          ...     ...           ...
# 618        2.24      IN  1.595481e+09
# 619        7.85      MG  1.595481e+09
# 621        4.70      PK  1.595481e+09
# 622        1.34      KE  1.595481e+09
# 623       20.62      TC  1.595481e+09
#
# [573 rows x 9 columns]

# %%
Cities_Weather.to_csv("Output.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
Cities_Weather.loc[Cities_Weather["Humidity"]>100]  #Skipped this step as there are no cities that have humidity > 100%
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, MaxTemp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_axis = Cities_Weather["Lat"]
y_axis = Cities_Weather["MaxTemp"]
plt.scatter(x_axis,y_axis,marker="o",color="green")
plt.xlabel("Latitude")
plt.ylabel("Max Temperaturer(F)")
plt.title(f'City Latitude vs. Max Temperature ({time.strftime("%m/%d/%Y")})')  #https://docs.python.org/3/library/time.html#time.strftime
plt.grid()
plt.savefig("Output/Latitude vs. Max Temperature.jpeg")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_axis = Cities_Weather["Lat"]
y_axis = Cities_Weather["Humidity"]
plt.scatter(x_axis,y_axis,marker="o",color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title(f'City Latitude v/s Humidity ({time.strftime("%m/%d/%Y")})')
plt.grid()
plt.savefig("Output/Latitude vs. Humidity.jpeg")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_axis = Cities_Weather["Lat"]
y_axis = Cities_Weather["Cloudiness"]
plt.scatter(x_axis,y_axis,marker="o",color="blue")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f'City Latitude v/s Cloudiness ({time.strftime("%m/%d/%Y")})')
plt.grid()
plt.savefig("Output/Latitude vs. Cloudiness.jpeg")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_axis = Cities_Weather["Lat"]
y_axis = Cities_Weather["Wind Speed"]
plt.scatter(x_axis,y_axis,marker='o',color='orange')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title(f'City latitude v/s Wind Speed ({time.strftime("%m/%d/%Y")})')
plt.grid()
plt.savefig("Output/Latitude vs. WindSpeed.jpeg")

# %% [markdown]
# ## Linear Regression

# %% [markdown]
#  ### Created Northern and Southern Hemisphere DataFrames

# %%
Northern_Hemisphere = Cities_Weather.loc[Cities_Weather["Lat"]>=0]

# %%
Northern_Hemisphere
# Out:
#                 City    Lat     Lng  MaxTemp  Humidity  Cloudiness  \
# 0            margate  51.38    1.39    61.00      70.0        15.0
# 2       beringovskiy  63.05  179.32    52.52      73.0         0.0
# 4              yalta  44.50   34.17    75.63      52.0         0.0
# 7             orange  33.70 -117.77    66.20      72.0        75.0
# 9           ano mera  37.45   25.40    78.80      69.0        20.0
# ..               ...    ...     ...      ...       ...         ...
# 613           lethem   3.38  -59.80    73.92      89.0       100.0
# 614        ugoofaaru   5.67   73.00    82.36      81.0        89.0
# 618  manavalakurichi   8.13   77.30    87.80      66.0        40.0
# 621          kharian  32.81   73.86    87.80      55.0         0.0
# 623    cockburn town  21.46  -71.14    82.81      79.0        17.0
#
#      Wind Speed Country          Date
# 0          1.99      GB  1.595481e+09
# 2         14.00      RU  1.595481e+09
# 4          5.61      UA  1.595481e+09
# 7          4.70      US  1.595481e+09
# 9         26.40      GR  1.595481e+09
# ..          ...     ...           ...
# 613        5.35      GY  1.595481e+09
# 614       19.62      MV  1.595481e+09
# 618        2.24      IN  1.595481e+09
# 621        4.70      PK  1.595481e+09
# 623       20.62      TC  1.595481e+09
#
# [410 rows x 9 columns]

# %%
Southern_Hemisphere = Cities_Weather.loc[Cities_Weather["Lat"]<0]
Southern_Hemisphere
# Out:
#                 City    Lat     Lng  MaxTemp  Humidity  Cloudiness  \
# 1       puerto ayora  -0.74  -90.35    69.01      93.0        98.0
# 3    arraial do cabo -22.97  -42.03    70.43      87.0         0.0
# 5             hobart -42.88  147.33    55.40      43.0        75.0
# 8         walvis bay -22.96   14.51    60.80      31.0         0.0
# 10       port alfred -33.59   26.89    63.12      37.0         0.0
# ..               ...    ...     ...      ...       ...         ...
# 615          honiara  -9.43  159.95    86.00      74.0        40.0
# 616           sampit  -2.53  112.95    84.88      80.0        49.0
# 617           beloha -25.17   45.05    62.08      77.0        92.0
# 619         manakara -22.13   48.02    61.47      82.0        30.0
# 622            ngong  -1.36   36.66    57.20      87.0        75.0
#
#      Wind Speed Country          Date
# 1          4.00      EC  1.595481e+09
# 3         10.51      BR  1.595481e+09
# 5         13.87      AU  1.595481e+09
# 8         11.41      NA  1.595481e+09
# 10         5.35      ZA  1.595481e+09
# ..          ...     ...           ...
# 615       13.87      SB  1.595481e+09
# 616        5.14      ID  1.595481e+09
# 617       15.41      MG  1.595481e+09
# 619        7.85      MG  1.595481e+09
# 622        1.34      KE  1.595481e+09
#
# [163 rows x 9 columns]

# %% [markdown]
# #### Created a function to create Linear Regression plots

# %%
def Regression( x_values,y_values):
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
    regress_values = x_values*slope+intercept
    line_eq = "y=" +str(round(slope,2)) + "x+" + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(min(x_values),(min(y_values)+20)),fontsize=20,color="red")
    print(f"The r-squared is : {rvalue**2}")
    return

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = Northern_Hemisphere["Lat"]
y_axis = Northern_Hemisphere["MaxTemp"]
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/NH Temp vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.40219571080482874

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = Southern_Hemisphere["Lat"]
y_axis = Southern_Hemisphere["MaxTemp"]
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/SH Temp vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.5277452926259352

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = Northern_Hemisphere["Lat"]
y_axis = Northern_Hemisphere["Humidity"]
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/NH Humidity vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.00875302856030666

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = Southern_Hemisphere["Lat"]
y_axis = Southern_Hemisphere["Humidity"]
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/SH Humidity vs.Latitude.jpeg")
# Out:
# The r-squared is : 6.372419317671908e-05

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = Northern_Hemisphere["Lat"]
y_axis = Northern_Hemisphere["Cloudiness"]
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/NH Cloudiness vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.00896851513854538

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = Southern_Hemisphere["Lat"]
y_axis = Southern_Hemisphere["Cloudiness"]
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/SH Cloudiness vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.010959252737109189

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = Northern_Hemisphere["Lat"]
y_axis = Northern_Hemisphere["Wind Speed"]
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/NH WindSpeed vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.00968124904012291

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = Southern_Hemisphere["Lat"]
y_axis = Southern_Hemisphere["Wind Speed"]
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/SH WindSpeed vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.0021334366556628724

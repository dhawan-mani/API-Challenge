# %% [markdown]
# #WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import time
import json
from scipy.stats import linregress
import scipy.stats as st
from api_keys import weather_api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#List for holding lat_lngs and cities
Lat_lng = []
cities = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
len(cities)
cities[0]
# Out:
# 'rikitea'

# %%
Cities_Dict = {"City":cities,"Lat":"","Lng":"","MaxTemp":"","Humidity":"","Cloudiness":"","Wind Speed":"","Country":"","Date":""}
Cities_df = pd.DataFrame(Cities_Dict)
Cities_df
# Out:
#                          City Lat Lng MaxTemp Humidity Cloudiness Wind Speed  \
# 0                     rikitea
# 1       mayor pablo lagerenza
# 2                       lagoa
# 3                komsomolskiy
# 4                   mahebourg
# ..                        ...  ..  ..     ...      ...        ...        ...
# 589  saint-marc-des-carrieres
# 590                   caconda
# 591           aleksandrov gay
# 592                     wagar
# 593                       ati
#
#     Country Date
# 0
# 1
# 2
# 3
# 4
# ..      ...  ...
# 589
# 590
# 591
# 592
# 593
#
# [594 rows x 9 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
record_number = 1
set_number = 1
print("Beginning data retrieval")
print("---------------------------------")
for index,row in Cities_df.iterrows():
    city = row['City']
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=Imperial"
    response = requests.get(url).json()
    try:
        print(f"Processing Record {record_number} of Set {set_number} | {city}")
        Cities_df.loc[index,"Lat"] = response["coord"]["lat"]
        Cities_df.loc[index,"Lng"] = response["coord"]["lon"]
        Cities_df.loc[index,"MaxTemp"] = response["main"]["temp_max"]
        Cities_df.loc[index,"Humidity"] = response["main"]["humidity"]
        Cities_df.loc[index,"Cloudiness"] = response["clouds"]["all"]
        Cities_df.loc[index,"Wind Speed"] = response["wind"]["speed"]
        Cities_df.loc[index,"Country"] = response["sys"]["country"]
        Cities_df.loc[index,"Date"] = response["dt"]
    except (KeyError,IndexError):
        print("City not found.Skipping......")
    record_number = record_number+1
    if record_number==51:
        set_number = set_number + 1
        record_number = 1
print("-------------------------")   
print("Data Retrieval Complete")
print("-------------------------")
#print(json.dumps(response,indent = 4,sort_keys=True))
# counter = 0
# set = 1
# for index,row in Cities_df.iterrows():
#     url = "api.openweathermap.org/data/2.5/weather?q={row['city']}&appid={weather_api_key}"
#     response = requests.get(url).json()

#     try:
#          print(f"Processing Record {counter} of Set {set}|{row["City"]}")
#     except (KeyError,IndexError):
#         print("city not found")
# counter = counter + 1
# if counter == 50:
#     set = set + 1
# Out:
# Beginning data retrieval
# ---------------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | mayor pablo lagerenza
# Processing Record 3 of Set 1 | lagoa
# Processing Record 4 of Set 1 | komsomolskiy
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | nizwa
# Processing Record 8 of Set 1 | mys shmidta
# City not found.Skipping......
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | westport
# Processing Record 11 of Set 1 | mrirt
# City not found.Skipping......
# Processing Record 12 of Set 1 | praia
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | port lincoln
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | amontada
# Processing Record 20 of Set 1 | vsevolodo-vilva
# ...

# %%
Cities_df
# Out:
#                          City    Lat     Lng MaxTemp Humidity Cloudiness  \
# 0                     rikitea -23.12 -134.97   70.61       80         18
# 1       mayor pablo lagerenza -19.93  -60.77   52.77       55         98
# 2                       lagoa  39.05  -27.98   71.37       88          0
# 3                komsomolskiy  40.43   71.72    84.2       37         19
# 4                   mahebourg -20.41    57.7    69.8       68         75
# ..                        ...    ...     ...     ...      ...        ...
# 589  saint-marc-des-carrieres  46.68  -72.05      75       70         40
# 590                   caconda -13.73   15.07   43.41       84          2
# 591           aleksandrov gay  50.15   48.57   72.03       41          0
# 592                     wagar  16.15    36.2   80.62       62        100
# 593                       ati  13.22   18.34   81.64       58         30
#
#     Wind Speed Country        Date
# 0        22.06      PF  1595737281
# ...

# %%
Cities_Weather = Cities_df.replace('', np.nan)

# %%
Cities_Weather.dropna(inplace=True)

# %%
New = Cities_Weather.isnull()

# %%
New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 540 entries, 0 to 593
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        540 non-null    bool
#  1   Lat         540 non-null    bool
#  2   Lng         540 non-null    bool
#  3   MaxTemp     540 non-null    bool
#  4   Humidity    540 non-null    bool
#  5   Cloudiness  540 non-null    bool
#  6   Wind Speed  540 non-null    bool
#  7   Country     540 non-null    bool
#  8   Date        540 non-null    bool
# dtypes: bool(9)
# memory usage: 9.0 KB

# %%
Cities_Weather
# Out:
#                          City    Lat     Lng  MaxTemp  Humidity  Cloudiness  \
# 0                     rikitea -23.12 -134.97    70.61      80.0        18.0
# 1       mayor pablo lagerenza -19.93  -60.77    52.77      55.0        98.0
# 2                       lagoa  39.05  -27.98    71.37      88.0         0.0
# 3                komsomolskiy  40.43   71.72    84.20      37.0        19.0
# 4                   mahebourg -20.41   57.70    69.80      68.0        75.0
# ..                        ...    ...     ...      ...       ...         ...
# 589  saint-marc-des-carrieres  46.68  -72.05    75.00      70.0        40.0
# 590                   caconda -13.73   15.07    43.41      84.0         2.0
# 591           aleksandrov gay  50.15   48.57    72.03      41.0         0.0
# 592                     wagar  16.15   36.20    80.62      62.0       100.0
# 593                       ati  13.22   18.34    81.64      58.0        30.0
#
#      Wind Speed Country          Date
# ...

# %%
Cities_Weather.to_csv("Output.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
Cities_Weather.loc[Cities_Weather["Humidity"]>100]  #Skipped this step as there are no cities that have humidity > 100%
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, MaxTemp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_axis = Cities_Weather["Lat"]
y_axis = Cities_Weather["MaxTemp"]
plt.scatter(x_axis,y_axis,marker="o",color="green")
plt.xlabel("Latitude")
plt.ylabel("Max Temperaturer(F)")
plt.title(f'City Latitude vs. Max Temperature ({time.strftime("%m/%d/%Y")})')  #https://docs.python.org/3/library/time.html#time.strftime
plt.grid()
plt.savefig("Output/Latitude vs. Max Temperature.jpeg")

# %% [raw]
# Analysis:
# The Latitude vs. MaxTemp plot shows that the maximum temperature peak is seen  in the range of -20 to 20 from the equator.
# This is due to the reason that sunlight falls within the latitude of -23 to +23.
# This region gets the most sunlight and have the highest temperature ranges.
# This fact is corroborate by our scatter plot.
# Also known as Tropic of Capricorn & Tropic of cancer respectively.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_axis = Cities_Weather["Lat"]
y_axis = Cities_Weather["Humidity"]
plt.scatter(x_axis,y_axis,marker="o",color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title(f'City Latitude v/s Humidity ({time.strftime("%m/%d/%Y")})')
plt.grid()
plt.savefig("Output/Latitude vs. Humidity.jpeg")

# %% [raw]
# Humidity & latitude are not directly proportional to each other.However from the graph we draw 2 conclusions which are as follows:
# 1) Most of the cities data show high humidity because right now in the middle of peak summer and as we know high temperatures translate to high humidity.
# This is validated by the fact that most data points in humidity access range from low 40's to high 90's and this is seen across cities in all latitiude ranges.
# 2)The density of humidity data points give us another interesting observation.Most of the humidity data points are concentrated in the latitude range [-20,+20]. This is simply because most cities lie within this latitude range & there are lesser number of cities as we move further north or south.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_axis = Cities_Weather["Lat"]
y_axis = Cities_Weather["Cloudiness"]
plt.scatter(x_axis,y_axis,marker="o",color="blue")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f'City Latitude v/s Cloudiness ({time.strftime("%m/%d/%Y")})')
plt.grid()
plt.savefig("Output/Latitude vs. Cloudiness.jpeg")

# %% [raw]
# Analysis:
# One conclusion that we can draw from this plot is there is a ceratin uniformity in cloudiness distribution across cities in all latitudes from North to south.
# For example:We see that there are dense data points in the cloudiness ranges 0,20,40,77 and 100.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_axis = Cities_Weather["Lat"]
y_axis = Cities_Weather["Wind Speed"]
plt.scatter(x_axis,y_axis,marker='o',color='orange')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title(f'City latitude v/s Wind Speed ({time.strftime("%m/%d/%Y")})')
plt.grid()
plt.savefig("Output/Latitude vs. WindSpeed.jpeg")

# %% [raw]
# Analysis:
# From this plot,we can conclude that maximum wind speed lies between the range of 0 to 10 mph.
# This means that most of the cities don't have windy season right now.
# The data points are more dense or closer to each other towards the North.They show uniformity in wind speed.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
#  ### Created Northern and Southern Hemisphere DataFrames

# %%
Northern_Hemisphere = Cities_Weather.loc[Cities_Weather["Lat"]>=0]

# %%
Northern_Hemisphere
# Out:
#                          City    Lat    Lng  MaxTemp  Humidity  Cloudiness  \
# 2                       lagoa  39.05 -27.98    71.37      88.0         0.0
# 3                komsomolskiy  40.43  71.72    84.20      37.0        19.0
# 5                      albany  42.60 -73.97    73.99      95.0        26.0
# 6                       nizwa  22.93  57.53    85.87      51.0        82.0
# 9                    westport  41.14 -73.36    78.80      83.0         1.0
# ..                        ...    ...    ...      ...       ...         ...
# 588                nouadhibou  20.93 -17.03    69.80      88.0        75.0
# 589  saint-marc-des-carrieres  46.68 -72.05    75.00      70.0        40.0
# 591           aleksandrov gay  50.15  48.57    72.03      41.0         0.0
# 592                     wagar  16.15  36.20    80.62      62.0       100.0
# 593                       ati  13.22  18.34    81.64      58.0        30.0
#
#      Wind Speed Country          Date
# ...

# %%
Southern_Hemisphere = Cities_Weather.loc[Cities_Weather["Lat"]<0]
Southern_Hemisphere
# Out:
#                       City    Lat     Lng  MaxTemp  Humidity  Cloudiness  \
# 0                  rikitea -23.12 -134.97    70.61      80.0        18.0
# 1    mayor pablo lagerenza -19.93  -60.77    52.77      55.0        98.0
# 4                mahebourg -20.41   57.70    69.80      68.0        75.0
# 8                hithadhoo  -0.60   73.08    83.16      65.0       100.0
# 12               busselton -33.65  115.33    63.00      73.0         0.0
# ..                     ...    ...     ...      ...       ...         ...
# 577                kavieng  -2.57  150.80    85.87      72.0        50.0
# 582                 neiafu -18.65 -173.98    77.00      73.0        40.0
# 584               cururupu  -1.83  -44.87    72.19      95.0        76.0
# 586            finschhafen  -6.60  147.87    82.63      73.0       100.0
# 590                caconda -13.73   15.07    43.41      84.0         2.0
#
#      Wind Speed Country          Date
# 0         22.06      PF  1.595737e+09
# ...

# %% [markdown]
# #### Created a function to create Linear Regression plots

# %%
def Regression( x_values,y_values):
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
    regress_values = x_values*slope+intercept
    line_eq = "y=" +str(round(slope,2)) + "x+" + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(min(x_values),(min(y_values)+20)),fontsize=20,color="red")
    print(f"The r-squared is : {rvalue**2}")
    return

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = Northern_Hemisphere["Lat"]
y_axis = Northern_Hemisphere["MaxTemp"]
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/NH Temp vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.4370034972018374

# %% [raw]
# Analysis:
# In statistics,r-squared is the coefficient of determination.
# It is the proportion of the variance in the dependent variable that is predictable from the independent variable(s).
# R2 is a statistic that will give some information about the goodness of fit of a model.
# In regression, the R2 coefficient of determination is a statistical measure of how well the regression predictions approximate the real data points.
# In this case our dependent variable is MaxTemp and independent variable is Latitude.In this  case 43% of the variability of the dependent variable has been accounted for and 57% of the variability is still unaccounted for.
# Also,maximum no. of data points are aligned along the regression line.
# The Regression line also explains that as we go far from the equator,the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = Southern_Hemisphere["Lat"]
y_axis = Southern_Hemisphere["MaxTemp"]
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/SH Temp vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.4332876198902855

# %% [raw]
# Analysis:
# In this the data points are closer and dense to the regression line above the line.
# The slope of the regression line is going upwardrs as we go toward equator.
# The observable trend is that the Max.Temperature incress along the line

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = Northern_Hemisphere["Lat"]
y_axis = Northern_Hemisphere["Humidity"]
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/NH Humidity vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.00875302856030666

# %% [raw]
# The Coefficient of determination is very low in this case i.e. just 0.8% variability of dependent variable is accounted for.
# Here we see that slope of the regression line is almost flat.
# Humidity is not actually related to the latitude ranges

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = Southern_Hemisphere["Lat"]
y_axis = Southern_Hemisphere["Humidity"]
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/SH Humidity vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.00022026883727679076

# %% [raw]
# The southern Hemisphere data shows a flat regression line and very very low coefficient of determination appx. 0.02%.
# So this also proves that in the southern hemisphere humidity and latitude are not related to each other.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = Northern_Hemisphere["Lat"]
y_axis = Northern_Hemisphere["Cloudiness"]
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/NH Cloudiness vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.00896851513854538

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = Southern_Hemisphere["Lat"]
y_axis = Southern_Hemisphere["Cloudiness"]
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/SH Cloudiness vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.010959252737109189

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = Northern_Hemisphere["Lat"]
y_axis = Northern_Hemisphere["Wind Speed"]
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/NH WindSpeed vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.00968124904012291

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = Southern_Hemisphere["Lat"]
y_axis = Southern_Hemisphere["Wind Speed"]
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
Regression(x_axis,y_axis)
plt.savefig("Output/Regression Output/SH WindSpeed vs.Latitude.jpeg")
# Out:
# The r-squared is : 0.0021334366556628724

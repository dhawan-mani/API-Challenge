# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
import ipywidgets as widgets
from ipywidgets.embed import embed_minimal_html

# Import API key
from api_keys import g_key
gmaps.configure(api_key=g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
Df = pd.read_csv("../WeatherPy/Output.csv")

# %%
Weather_Data = Df.iloc[:,1:10]
Weather_Data
# Out:
#                          City    Lat     Lng  MaxTemp  Humidity  Cloudiness  \
# 0                     rikitea -23.12 -134.97    70.61      80.0        18.0
# 1       mayor pablo lagerenza -19.93  -60.77    52.77      55.0        98.0
# 2                       lagoa  39.05  -27.98    71.37      88.0         0.0
# 3                komsomolskiy  40.43   71.72    84.20      37.0        19.0
# 4                   mahebourg -20.41   57.70    69.80      68.0        75.0
# ..                        ...    ...     ...      ...       ...         ...
# 535  saint-marc-des-carrieres  46.68  -72.05    75.00      70.0        40.0
# 536                   caconda -13.73   15.07    43.41      84.0         2.0
# 537           aleksandrov gay  50.15   48.57    72.03      41.0         0.0
# 538                     wagar  16.15   36.20    80.62      62.0       100.0
# 539                       ati  13.22   18.34    81.64      58.0        30.0
#
#      Wind Speed Country          Date
# 0         22.06      PF  1.595737e+09
# 1          1.48      PY  1.595737e+09
# 2         17.67      PT  1.595737e+09
# 3          9.17      UZ  1.595737e+09
# 4         16.11      MU  1.595737e+09
# ..          ...     ...           ...
# 535        2.24      CA  1.595737e+09
# 536        1.28      AO  1.595737e+09
# 537        4.63      RU  1.595737e+09
# 538       17.29      SD  1.595737e+09
# 539        8.46      TD  1.595737e+09
#
# [540 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
locations = Weather_Data[["Lat","Lng"]]
Weights = Weather_Data["Humidity"].astype(float)

# %%
figure_layout = {           #Setting figure attributes
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

heat_layer = gmaps.heatmap_layer(locations, weights=Weights,           #Setting the heatmap layer
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

fig = gmaps.figure(layout=figure_layout,zoom_level=2,center=(15,25))
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
embed_minimal_html('export.html', views=[fig]) #Exporting the file with image of the map

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
Hotel_df = Weather_Data.loc[(Weather_Data["MaxTemp"] >50) & (Weather_Data["MaxTemp"]<80) & (Weather_Data["Wind Speed"]<10) & (Weather_Data["Cloudiness"]==0)]

# %%
Hotel_df.reset_index(inplace=True)

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = Hotel_df.iloc[:,1:10]

# %%
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#                      City    Lat     Lng  MaxTemp  Humidity  Cloudiness  \
# 0               busselton -33.65  115.33    63.00      73.0         0.0
# 1                     gat  31.61   34.76    75.00      61.0         0.0
# 2            ponta do sol  32.67  -17.10    64.99      77.0         0.0
# 3   sao jose do rio pardo -21.60  -46.89    59.83      67.0         0.0
# 4          port shepstone -30.74   30.45    60.58      32.0         0.0
# 5               kovernino  57.13   43.81    58.48      74.0         0.0
# 6             east london -33.02   27.91    62.60      45.0         0.0
# 7             henties bay -22.12   14.28    64.00      37.0         0.0
# 8             new norfolk -42.78  147.06    57.99      75.0         0.0
# 9                   vardo  70.37   31.11    58.37      66.0         0.0
# 10                 chokwe -24.53   32.98    54.52      92.0         0.0
# 11                  suluq  31.67   20.25    69.76      87.0         0.0
# 12                archena  38.12   -1.30    75.99      90.0         0.0
# 13                vilhena -12.74  -60.15    62.76      60.0         0.0
# 14            palafrugell  41.92    3.16    69.01      50.0         0.0
# 15         porto nacional -10.71  -48.42    68.00      72.0         0.0
# 16            antofagasta -23.65  -70.40    51.80      81.0         0.0
# 17               sidi ali  36.10    0.42    77.07      43.0         0.0
# 18                buritis -15.62  -46.42    62.02      58.0         0.0
# 19                hakkari  37.58   44.17    73.20      24.0         0.0
# 20     sao felix do xingu  -6.64  -51.99    69.78      57.0         0.0
# 21                 batken  39.83   71.00    66.11      44.0         0.0
# 22            piracanjuba -17.30  -49.02    62.47      54.0         0.0
# 23               luderitz -26.65   15.16    51.80      93.0         0.0
# 24                   lena  43.10   -5.73    64.99      92.0         0.0
# 25                parabel  58.70   81.48    65.89      51.0         0.0
# 26              zemlyansk  51.90   38.73    60.80      51.0         0.0
# 27                   surt  31.21   16.59    76.57      72.0         0.0
# 28                 niksar  40.59   36.95    68.72      65.0         0.0
# 29               ampanihy -24.70   44.75    52.50      85.0         0.0
# 30               tarancon  40.01   -3.01    78.01      45.0         0.0
# 31               petrovsk  52.31   45.39    62.04      71.0         0.0
# 32             tolaga bay -38.37  178.30    53.42      66.0         0.0
# 33               kargasok  59.06   80.86    65.19      51.0         0.0
# 34              omsukchan  62.53  155.80    79.23      25.0         0.0
# 35        aleksandrov gay  50.15   48.57    72.03      41.0         0.0
#
#     Wind Speed Country          Date Hotel Name
# 0         3.00      AU  1.595737e+09
# 1         0.81      IL  1.595737e+09
# 2         3.96      PT  1.595737e+09
# 3         4.29      BR  1.595737e+09
# 4         6.31      ZA  1.595737e+09
# 5         4.45      RU  1.595737e+09
# 6         8.05      ZA  1.595737e+09
# 7         3.00     NaN  1.595737e+09
# 8         2.08      AU  1.595737e+09
# 9         9.01      NO  1.595737e+09
# 10        2.21      MZ  1.595737e+09
# 11        4.88      LY  1.595737e+09
# 12        1.10      ES  1.595737e+09
# 13        3.06      BR  1.595737e+09
# 14        1.50      ES  1.595737e+09
# 15        4.70      BR  1.595737e+09
# 16        2.24      CL  1.595737e+09
# 17        1.77      DZ  1.595737e+09
# 18        2.15      BR  1.595737e+09
# 19        3.87      TR  1.595737e+09
# 20        1.57      BR  1.595737e+09
# 21        5.21      KG  1.595737e+09
# 22        6.33      BR  1.595737e+09
# 23        6.93     NaN  1.595737e+09
# 24        1.12      ES  1.595737e+09
# 25        7.67      RU  1.595737e+09
# 26        6.71      RU  1.595737e+09
# 27        7.05      LY  1.595737e+09
# 28        3.18      TR  1.595737e+09
# 29        7.58      MG  1.595737e+09
# 30        4.70      ES  1.595737e+09
# 31        5.32      RU  1.595737e+09
# 32        8.48      NZ  1.595737e+09
# 33        8.21      RU  1.595737e+09
# 34        9.86      RU  1.595737e+09
# 35        4.63      RU  1.595737e+09

# %%
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "key" : g_key,
    "radius": 5000,
    "types":"hotel" ,
    "keyword" :"Nearby Hotel"}
for index,row in hotel_df.iterrows():   #Using iterows to get the Hotel names and entering the data inside the data frame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    response = requests.get(url,params=params).json()
    if (len(response["results"]) > 0):
        hotel_df.loc[index,"Hotel Name"] = response["results"][0]["name"]
print("DONE")
hotel_df
# Out:
# DONE
#                      City    Lat     Lng  MaxTemp  Humidity  Cloudiness  \
# 0               busselton -33.65  115.33    63.00      73.0         0.0
# 1                     gat  31.61   34.76    75.00      61.0         0.0
# 2            ponta do sol  32.67  -17.10    64.99      77.0         0.0
# 3   sao jose do rio pardo -21.60  -46.89    59.83      67.0         0.0
# 4          port shepstone -30.74   30.45    60.58      32.0         0.0
# 5               kovernino  57.13   43.81    58.48      74.0         0.0
# 6             east london -33.02   27.91    62.60      45.0         0.0
# 7             henties bay -22.12   14.28    64.00      37.0         0.0
# 8             new norfolk -42.78  147.06    57.99      75.0         0.0
# 9                   vardo  70.37   31.11    58.37      66.0         0.0
# 10                 chokwe -24.53   32.98    54.52      92.0         0.0
# 11                  suluq  31.67   20.25    69.76      87.0         0.0
# 12                archena  38.12   -1.30    75.99      90.0         0.0
# 13                vilhena -12.74  -60.15    62.76      60.0         0.0
# 14            palafrugell  41.92    3.16    69.01      50.0         0.0
# 15         porto nacional -10.71  -48.42    68.00      72.0         0.0
# 16            antofagasta -23.65  -70.40    51.80      81.0         0.0
# 17               sidi ali  36.10    0.42    77.07      43.0         0.0
# 18                buritis -15.62  -46.42    62.02      58.0         0.0
# 19                hakkari  37.58   44.17    73.20      24.0         0.0
# 20     sao felix do xingu  -6.64  -51.99    69.78      57.0         0.0
# 21                 batken  39.83   71.00    66.11      44.0         0.0
# 22            piracanjuba -17.30  -49.02    62.47      54.0         0.0
# 23               luderitz -26.65   15.16    51.80      93.0         0.0
# 24                   lena  43.10   -5.73    64.99      92.0         0.0
# 25                parabel  58.70   81.48    65.89      51.0         0.0
# 26              zemlyansk  51.90   38.73    60.80      51.0         0.0
# 27                   surt  31.21   16.59    76.57      72.0         0.0
# 28                 niksar  40.59   36.95    68.72      65.0         0.0
# 29               ampanihy -24.70   44.75    52.50      85.0         0.0
# 30               tarancon  40.01   -3.01    78.01      45.0         0.0
# 31               petrovsk  52.31   45.39    62.04      71.0         0.0
# 32             tolaga bay -38.37  178.30    53.42      66.0         0.0
# 33               kargasok  59.06   80.86    65.19      51.0         0.0
# 34              omsukchan  62.53  155.80    79.23      25.0         0.0
# 35        aleksandrov gay  50.15   48.57    72.03      41.0         0.0
#
#     Wind Speed Country          Date                            Hotel Name
# 0         3.00      AU  1.595737e+09                   The Sebel Busselton
# 1         0.81      IL  1.595737e+09                            Desert Gat
# 2         3.96      PT  1.595737e+09             Estalagem Da Ponta Do Sol
# 3         4.29      BR  1.595737e+09  Hotel & Pousada Recanto do Rio Pardo
# 4         6.31      ZA  1.595737e+09      The Tweni Waterfront Guest Lodge
# 5         4.45      RU  1.595737e+09                               Premium
# 6         8.05      ZA  1.595737e+09                  Premier Hotel Regent
# 7         3.00     NaN  1.595737e+09                        De Duine Hotel
# 8         2.08      AU  1.595737e+09            Tynwald Willow Bend Estate
# 9         9.01      NO  1.595737e+09                           Vardo Motel
# 10        2.21      MZ  1.595737e+09
# 11        4.88      LY  1.595737e+09
# 12        1.10      ES  1.595737e+09   Hotel Termas | Balneario de Archena
# 13        3.06      BR  1.595737e+09                          Hotel Mirage
# 14        1.50      ES  1.595737e+09            Mas de Torrent Hotel & Spa
# 15        4.70      BR  1.595737e+09                        Vereda's Hotel
# 16        2.24      CL  1.595737e+09   Exclusivo Apart Hotel puerto nuevo.
# 17        1.77      DZ  1.595737e+09
# 18        2.15      BR  1.595737e+09                          Plazza Hotel
# 19        3.87      TR  1.595737e+09
# 20        1.57      BR  1.595737e+09                 Apart Hotel Rio Xingu
# 21        5.21      KG  1.595737e+09
# 22        6.33      BR  1.595737e+09                    Hotel Santa Martha
# 23        6.93     NaN  1.595737e+09                   LÜDERITZ NEST HOTEL
# 24        1.12      ES  1.595737e+09
# 25        7.67      RU  1.595737e+09                               Levkada
# 26        6.71      RU  1.595737e+09
# 27        7.05      LY  1.595737e+09
# 28        3.18      TR  1.595737e+09                      Ayvaz Park Hotel
# 29        7.58      MG  1.595737e+09
# 30        4.70      ES  1.595737e+09     Complejo Enoturistico La Estacada
# 31        5.32      RU  1.595737e+09                         Scarlet Sails
# 32        8.48      NZ  1.595737e+09                        Tolaga Bay Inn
# 33        8.21      RU  1.595737e+09                        Hotel Kargasok
# 34        9.86      RU  1.595737e+09
# 35        4.63      RU  1.595737e+09

# %%
hotel_df = hotel_df.loc[(hotel_df["Hotel Name"]!="")]     #Locating the rows with non-null values.

# %%
hotel_df
# Out:
#                      City    Lat     Lng  MaxTemp  Humidity  Cloudiness  \
# 0               busselton -33.65  115.33    63.00      73.0         0.0
# 1                     gat  31.61   34.76    75.00      61.0         0.0
# 2            ponta do sol  32.67  -17.10    64.99      77.0         0.0
# 3   sao jose do rio pardo -21.60  -46.89    59.83      67.0         0.0
# 4          port shepstone -30.74   30.45    60.58      32.0         0.0
# 5               kovernino  57.13   43.81    58.48      74.0         0.0
# 6             east london -33.02   27.91    62.60      45.0         0.0
# 7             henties bay -22.12   14.28    64.00      37.0         0.0
# 8             new norfolk -42.78  147.06    57.99      75.0         0.0
# 9                   vardo  70.37   31.11    58.37      66.0         0.0
# 12                archena  38.12   -1.30    75.99      90.0         0.0
# 13                vilhena -12.74  -60.15    62.76      60.0         0.0
# 14            palafrugell  41.92    3.16    69.01      50.0         0.0
# 15         porto nacional -10.71  -48.42    68.00      72.0         0.0
# 16            antofagasta -23.65  -70.40    51.80      81.0         0.0
# 18                buritis -15.62  -46.42    62.02      58.0         0.0
# 20     sao felix do xingu  -6.64  -51.99    69.78      57.0         0.0
# 22            piracanjuba -17.30  -49.02    62.47      54.0         0.0
# 23               luderitz -26.65   15.16    51.80      93.0         0.0
# 25                parabel  58.70   81.48    65.89      51.0         0.0
# 28                 niksar  40.59   36.95    68.72      65.0         0.0
# 30               tarancon  40.01   -3.01    78.01      45.0         0.0
# 31               petrovsk  52.31   45.39    62.04      71.0         0.0
# 32             tolaga bay -38.37  178.30    53.42      66.0         0.0
# 33               kargasok  59.06   80.86    65.19      51.0         0.0
#
#     Wind Speed Country          Date                            Hotel Name
# 0         3.00      AU  1.595737e+09                   The Sebel Busselton
# 1         0.81      IL  1.595737e+09                            Desert Gat
# 2         3.96      PT  1.595737e+09             Estalagem Da Ponta Do Sol
# 3         4.29      BR  1.595737e+09  Hotel & Pousada Recanto do Rio Pardo
# 4         6.31      ZA  1.595737e+09      The Tweni Waterfront Guest Lodge
# 5         4.45      RU  1.595737e+09                               Premium
# 6         8.05      ZA  1.595737e+09                  Premier Hotel Regent
# 7         3.00     NaN  1.595737e+09                        De Duine Hotel
# 8         2.08      AU  1.595737e+09            Tynwald Willow Bend Estate
# 9         9.01      NO  1.595737e+09                           Vardo Motel
# 12        1.10      ES  1.595737e+09   Hotel Termas | Balneario de Archena
# 13        3.06      BR  1.595737e+09                          Hotel Mirage
# 14        1.50      ES  1.595737e+09            Mas de Torrent Hotel & Spa
# 15        4.70      BR  1.595737e+09                        Vereda's Hotel
# 16        2.24      CL  1.595737e+09   Exclusivo Apart Hotel puerto nuevo.
# 18        2.15      BR  1.595737e+09                          Plazza Hotel
# 20        1.57      BR  1.595737e+09                 Apart Hotel Rio Xingu
# 22        6.33      BR  1.595737e+09                    Hotel Santa Martha
# 23        6.93     NaN  1.595737e+09                   LÜDERITZ NEST HOTEL
# 25        7.67      RU  1.595737e+09                               Levkada
# 28        3.18      TR  1.595737e+09                      Ayvaz Park Hotel
# 30        4.70      ES  1.595737e+09     Complejo Enoturistico La Estacada
# 31        5.32      RU  1.595737e+09                         Scarlet Sails
# 32        8.48      NZ  1.595737e+09                        Tolaga Bay Inn
# 33        8.21      RU  1.595737e+09                        Hotel Kargasok

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
markers = gmaps.marker_layer(locations,info_box_content=hotel_info)
fig.add_layer(markers)

embed_minimal_html('Markers.html', views=[fig])        #Reference:https://jupyter-gmaps.readthedocs.io/en/latest/export.html
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…
